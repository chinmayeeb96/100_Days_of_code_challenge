# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(plt.style.available)
#plt.style.use("seaborn-whitegrid")
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ## Importing datasets

# %%
train = '/home/chinmayee/my_machine_learning_journey/100_Days_of_code_challenge/Dataset/train.csv'
test = '/home/chinmayee/my_machine_learning_journey/100_Days_of_code_challenge/Dataset/test.csv'
df_train = pd.read_csv(train)
df_test = pd.read_csv(test)
plt.style.use("seaborn-whitegrid")
display(df_train)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Filling null values

# %%
from fill_nulldata import fill_nulldata

fill_nulldata(df_train)
fill_nulldata(df_test)

print(df_train.isnull().sum())
print(df_test.isnull().sum())
print(df_train.dtypes)
print(df_train['Cabin'])
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64
# PassengerId      int64
# Survived       float64
# Pclass         float64
# Name            object
# Sex             object
# Age            float64
# SibSp          float64
# Parch          float64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# 0      B96 B98
# 1          C85
# 2      B96 B98
# 3         C123
# 4      B96 B98
#         ...
# 886    B96 B98
# 887        B42
# 888    B96 B98
# 889       C148
# 890    B96 B98
# Name: Cabin, Length: 891, dtype: object

# %% [markdown]
# ## Correlation Matrix

# %%
correlation_matrix = df_train.corr()
correlation_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_60a3a_row0_col0,#T_60a3a_row1_col1,#T_60a3a_row2_col2,#T_60a3a_row3_col3,#T_60a3a_row4_col4,#T_60a3a_row5_col5,#T_60a3a_row6_col6{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_60a3a_row0_col1{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_60a3a_row0_col2{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_60a3a_row0_col3{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_60a3a_row0_col4,#T_60a3a_row3_col2{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_60a3a_row0_col5{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_60a3a_row0_col6{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_60a3a_row1_col0{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_60a3a_row1_col2{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_60a3a_row1_col3{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_60a3a_row1_col4{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_60a3a_row1_col5{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_60a3a_row1_col6{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_60a3a_row2_col0{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_60a3a_row2_col1,#T_60a3a_row2_col3,#T_60a3a_row2_col6,#T_60a3a_row3_col4,#T_60a3a_row3_col5,#T_60a3a_row4_col0,#T_60a3a_row6_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_60a3a_row2_col4{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_60a3a_row2_col5{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_60a3a_row3_col0{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_60a3a_row3_col1{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_60a3a_row3_col6{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_60a3a_row4_col1{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_60a3a_row4_col2{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_60a3a_row4_col3{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_60a3a_row4_col5{
#             background-color:  #dddcdc;
#             color:  #000000;
#         }#T_60a3a_row4_col6{
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }#T_60a3a_row5_col0{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_60a3a_row5_col1{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_60a3a_row5_col2{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_60a3a_row5_col3{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_60a3a_row5_col4{
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }#T_60a3a_row5_col6{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_60a3a_row6_col0{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_60a3a_row6_col1{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_60a3a_row6_col3,#T_60a3a_row6_col4{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_60a3a_row6_col5{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }</style><table id="T_60a3a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PassengerId</th>        <th class="col_heading level0 col1" >Survived</th>        <th class="col_heading level0 col2" >Pclass</th>        <th class="col_heading level0 col3" >Age</th>        <th class="col_heading level0 col4" >SibSp</th>        <th class="col_heading level0 col5" >Parch</th>        <th class="col_heading level0 col6" >Fare</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_60a3a_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#                         <td id="T_60a3a_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_60a3a_row0_col1" class="data row0 col1" >-0.005007</td>
#                         <td id="T_60a3a_row0_col2" class="data row0 col2" >-0.035144</td>
#                         <td id="T_60a3a_row0_col3" class="data row0 col3" >0.033207</td>
#                         <td id="T_60a3a_row0_col4" class="data row0 col4" >-0.057527</td>
#                         <td id="T_60a3a_row0_col5" class="data row0 col5" >-0.001652</td>
#                         <td id="T_60a3a_row0_col6" class="data row0 col6" >0.012658</td>
#             </tr>
#             <tr>
#                         <th id="T_60a3a_level0_row1" class="row_heading level0 row1" >Survived</th>
#                         <td id="T_60a3a_row1_col0" class="data row1 col0" >-0.005007</td>
#                         <td id="T_60a3a_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_60a3a_row1_col2" class="data row1 col2" >-0.338481</td>
#                         <td id="T_60a3a_row1_col3" class="data row1 col3" >-0.069809</td>
#                         <td id="T_60a3a_row1_col4" class="data row1 col4" >-0.035322</td>
#                         <td id="T_60a3a_row1_col5" class="data row1 col5" >0.081629</td>
#                         <td id="T_60a3a_row1_col6" class="data row1 col6" >0.257307</td>
#             </tr>
#             <tr>
#                         <th id="T_60a3a_level0_row2" class="row_heading level0 row2" >Pclass</th>
#                         <td id="T_60a3a_row2_col0" class="data row2 col0" >-0.035144</td>
#                         <td id="T_60a3a_row2_col1" class="data row2 col1" >-0.338481</td>
#                         <td id="T_60a3a_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_60a3a_row2_col3" class="data row2 col3" >-0.331339</td>
#                         <td id="T_60a3a_row2_col4" class="data row2 col4" >0.083081</td>
#                         <td id="T_60a3a_row2_col5" class="data row2 col5" >0.018443</td>
#                         <td id="T_60a3a_row2_col6" class="data row2 col6" >-0.549500</td>
#             </tr>
#             <tr>
#                         <th id="T_60a3a_level0_row3" class="row_heading level0 row3" >Age</th>
#                         <td id="T_60a3a_row3_col0" class="data row3 col0" >0.033207</td>
#                         <td id="T_60a3a_row3_col1" class="data row3 col1" >-0.069809</td>
#                         <td id="T_60a3a_row3_col2" class="data row3 col2" >-0.331339</td>
#                         <td id="T_60a3a_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_60a3a_row3_col4" class="data row3 col4" >-0.232625</td>
#                         <td id="T_60a3a_row3_col5" class="data row3 col5" >-0.179191</td>
#                         <td id="T_60a3a_row3_col6" class="data row3 col6" >0.091566</td>
#             </tr>
#             <tr>
#                         <th id="T_60a3a_level0_row4" class="row_heading level0 row4" >SibSp</th>
#                         <td id="T_60a3a_row4_col0" class="data row4 col0" >-0.057527</td>
#                         <td id="T_60a3a_row4_col1" class="data row4 col1" >-0.035322</td>
#                         <td id="T_60a3a_row4_col2" class="data row4 col2" >0.083081</td>
#                         <td id="T_60a3a_row4_col3" class="data row4 col3" >-0.232625</td>
#                         <td id="T_60a3a_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_60a3a_row4_col5" class="data row4 col5" >0.414838</td>
#                         <td id="T_60a3a_row4_col6" class="data row4 col6" >0.1
