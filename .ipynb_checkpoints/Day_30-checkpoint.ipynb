# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(plt.style.available)
#plt.style.use("seaborn-whitegrid")
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ## Importing datasets

# %%
train = '/home/chinmayee/my_machine_learning_journey/100_Days_of_code_challenge/Dataset/train.csv'
test = '/home/chinmayee/my_machine_learning_journey/100_Days_of_code_challenge/Dataset/test.csv'
df_train = pd.read_csv(train)
df_test = pd.read_csv(test)
plt.style.use("seaborn-whitegrid")
display(df_train)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Filling null values

# %%
from fill_nulldata import fill_nulldata

fill_nulldata(df_train)
fill_nulldata(df_test)

print(df_train.isnull().sum())
print(df_test.isnull().sum())
print(df_train.dtypes)
print(df_train['Cabin'])
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64
# PassengerId      int64
# Survived       float64
# Pclass         float64
# Name            object
# Sex             object
# Age            float64
# SibSp          float64
# Parch          float64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# 0      B96 B98
# 1          C85
# 2      B96 B98
# 3         C123
# 4      B96 B98
#         ...
# 886    B96 B98
# 887        B42
# 888    B96 B98
# 889       C148
# 890    B96 B98
# Name: Cabin, Length: 891, dtype: object

# %%
X = df_train.drop(['Survived', 'Name', 'Ticket', 'Cabin', 'PassengerId'], axis =1)
y = df_train['Survived']
X_t = df_test.drop(['Name', 'Ticket', 'Cabin', 'PassengerId'], axis = 1)

# %%
X = pd.get_dummies(X)
X_t = pd.get_dummies(X_t)
X.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  Embarked_C  \
# 0     3.0  22.0    1.0    0.0   7.2500           0         1           0
# 1     1.0  38.0    1.0    0.0  71.2833           1         0           1
# 2     3.0  26.0    0.0    0.0   7.9250           1         0           0
# 3     1.0  35.0    1.0    0.0  53.1000           1         0           0
# 4     3.0  35.0    0.0    0.0   8.0500           0         1           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %% [markdown]
# ## Correlation Matrix

# %%
correlation_matrix = X.corr()
correlation_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_162b2_row0_col0,#T_162b2_row1_col1,#T_162b2_row2_col2,#T_162b2_row3_col3,#T_162b2_row4_col4,#T_162b2_row5_col5,#T_162b2_row6_col6,#T_162b2_row7_col7,#T_162b2_row8_col8,#T_162b2_row9_col9{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_162b2_row0_col1,#T_162b2_row0_col4,#T_162b2_row1_col2,#T_162b2_row4_col0,#T_162b2_row5_col6,#T_162b2_row6_col3,#T_162b2_row6_col5,#T_162b2_row7_col9,#T_162b2_row9_col7,#T_162b2_row9_col8{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_162b2_row0_col2,#T_162b2_row4_col8{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_162b2_row0_col3{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_162b2_row0_col5{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_162b2_row0_col6{
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }#T_162b2_row0_col7{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_162b2_row0_col8,#T_162b2_row0_col9{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_162b2_row1_col0{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_162b2_row1_col3{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_162b2_row1_col4{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_162b2_row1_col5,#T_162b2_row2_col4,#T_162b2_row7_col6{
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }#T_162b2_row1_col6,#T_162b2_row7_col5{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_162b2_row1_col7{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_162b2_row1_col8{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_162b2_row1_col9{
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }#T_162b2_row2_col0,#T_162b2_row4_col6{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_162b2_row2_col1{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_162b2_row2_col3,#T_162b2_row7_col4{
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }#T_162b2_row2_col5{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_162b2_row2_col6{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_162b2_row2_col7,#T_162b2_row9_col0{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_162b2_row2_col8{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_162b2_row2_col9{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_162b2_row3_col0{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_162b2_row3_col1{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_162b2_row3_col2{
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }#T_162b2_row3_col4{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_162b2_row3_col5{
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }#T_162b2_row3_col6{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_162b2_row3_col7{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_162b2_row3_col8,#T_162b2_row8_col4{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_162b2_row3_col9{
#             background-color:  #d6dce4;
#             color:  #000000;
#         }#T_162b2_row4_col1,#T_162b2_row4_col2{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_162b2_row4_col3{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_162b2_row4_col5,#T_162b2_row4_col7{
#             background-color:  #f1cdba;
#             color:  #000000;
#         }#T_162b2_row4_col9{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_162b2_row5_col0{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_162b2_row5_col1{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_162b2_row5_col2,#T_162b2_row6_col8{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_162b2_row5_col3,#T_162b2_row6_col7{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_162b2_row5_col4{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_162b2_row5_col7{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_162b2_row5_col8{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_162b2_row5_col9{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_162b2_row6_col0,#T_162b2_row9_col5{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_162b2_row6_col1{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }#T_162b2_row6_col2{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_162b2_row6_col4{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_162b2_row6_col9{
#             background-color:  #dedcdb;
#             color:  #000000;
#         }#T_162b2_row7_col0{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_162b2_row7_col1{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_162b2_row7_col2{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_162b2_row7_col3{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_162b2_row7_col8,#T_162b2_row9_col1{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_162b2_row8_col0{
#             background-color:  #dcdddd;
#             color:  #000000;
#         }#T_162b2_row8_col1{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_162b2_row8_col2{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_162b2_row8_col3{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_162b2_row8_col5{
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }#T_162b2_row8_col6{
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }#T_162b2_row8_col7{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_162b2_row8_col9{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_162b2_row9_col2,#T_162b2_row9_col3{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_162b2_row9_col4{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_162b2_row9_col6{
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }</style><table id="T_162b2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pclass</th>        <th class="col_heading level0 col1" >Age</th>        <th class="col_heading level0 col2" >SibSp</th>        <th class="col_heading level0 col3" >Parch</th>        <th class="col_heading level0 col4" >Fare</th>        <th class="col_heading level0 col5" >Sex_female</th>        <th class="col_heading level0 col6" >Sex_male</th>        <th class="col_heading level0 col7" >Embarked_C</th>        <th class="col_heading level0 col8" >Embarked_Q</th>        <th class="col_heading level0 col9" >Embarked_S</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_162b2_level0_row0" class="row_heading level0 row0" >Pclass</th>
#                         <td id="T_162b2_row0_col0" class="dat

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score


clf1 = LogisticRegression(penalty='l2', 
                          C=0.001,
                          solver='lbfgs',
                          random_state=1)

clf2 = DecisionTreeClassifier(max_depth=1,
                              criterion='entropy',
                              random_state=0)

clf3 = KNeighborsClassifier(n_neighbors=1,
                            p=2,
                            metric='minkowski')

pipe1 = Pipeline([['sc', MinMaxScaler()],
                  ['clf', clf1]])
pipe3 = Pipeline([['sc', MinMaxScaler()],
                  ['clf', clf3]])

clf_labels = ['Logistic regression', 'Decision tree', 'KNN']

print('10-fold cross validation:\n')
for clf, label in zip([pipe1, clf2, pipe3], clf_labels):
    scores = cross_val_score(estimator=clf,
                             X=X,
                             y=y,
                             cv=10,
                             scoring='roc_auc')
    print(f'ROC AUC: {scores.mean():.2f} '
          f'(+/- {scores.std():.2f}) [{label}]')
# Out:
# 10-fold cross validation:
#
# ROC AUC: 0.85 (+/- 0.03) [Logistic regression]
# ROC AUC: 0.77 (+/- 0.04) [Decision tree]
# ROC AUC: 0.74 (+/- 0.05) [KNN]

# %%
# Majority Rule (hard) Voting
from MajorityVoteClassifier import MajorityVoteClassifier
mv_clf = MajorityVoteClassifier(classifiers=[pipe1, clf2, pipe3])

clf_labels += ['Majority voting']
all_clf = [pipe1, clf2, pipe3, mv_clf]

for clf, label in zip(all_clf, clf_labels):
    scores = cross_val_score(estimator=clf,
                             X=X,
                             y=y,
                             cv=10,
                             scoring='roc_auc')
    print(f'ROC AUC: {scores.mean():.2f} '
          f'(+/- {scores.std():.2f}) [{label}]')
# Out:
# ROC AUC: 0.85 (+/- 0.03) [Logistic regression]
# ROC AUC: 0.77 (+/- 0.04) [Decision tree]
# ROC AUC: 0.74 (+/- 0.05) [KNN]
# ROC AUC: 0.84 (+/- 0.04) [Majority voting]

# %%
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split


iris = datasets.load_iris()
X, y = iris.data[50:, [1, 2]], iris.target[50:]
le = LabelEncoder()
y = le.fit_transform(y)

X_train, X_test, y_train, y_test =\
       train_test_split(X, y, 
                        test_size=0.5, 
                        random_state=1,
                        stratify=y)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score


clf1 = LogisticRegression(penalty='l2', 
                          C=0.001,
                          solver='lbfgs',
                          random_state=1)

clf2 = DecisionTreeClassifier(max_depth=1,
                              criterion='entropy',
                              random_state=0)

clf3 = KNeighborsClassifier(n_neighbors=1,
                            p=2,
                            metric='minkowski')

pipe1 = Pipeline([['sc', StandardScaler()],
                  ['clf', clf1]])
pipe3 = Pipeline([['sc', StandardScaler()],
                  ['clf', clf3]])

clf_labels = ['Logistic regression', 'Decision tree', 'KNN']

print('10-fold cross validation:\n')
for clf, label in zip([pipe1, clf2, pipe3], clf_labels):
    scores = cross_val_score(estimator=clf,
                             X=X_train,
                             y=y_train,
                             cv=10,
                             scoring='roc_auc')
    print(f'ROC AUC: {scores.mean():.2f} '
          f'(+/- {scores.std():.2f}) [{label}]')
# Out:
# 10-fold cross validation:
#
# ROC AUC: 0.92 (+/- 0.15) [Logistic regression]
# ROC AUC: 0.87 (+/- 0.18) [Decision tree]
# ROC AUC: 0.85 (+/- 0.13) [KNN]

# %%
# Majority Rule (hard) Voting
from MajorityVoteClassifier import MajorityVoteClassifier
mv_clf = MajorityVoteClassifier(classifiers=[pipe1, clf2, pipe3])

clf_labels += ['Majority voting']
all_clf = [pipe1, clf2, pipe3, mv_clf]

for clf, label in zip(all_clf, clf_labels):
    scores = cross_val_score(estimator=clf,
                             X=X_train,
                             y=y_train,
                             cv=10,
                             scoring='roc_auc')
    print(f'ROC AUC: {scores.mean():.2f} '
          f'(+/- {scores.std():.2f}) [{label}]')
# Out:
# ROC AUC: 0.92 (+/- 0.15) [Logistic regression]
# ROC AUC: 0.87 (+/- 0.18) [Decision tree]
# ROC AUC: 0.85 (+/- 0.13) [KNN]
# ROC AUC: 0.98 (+/- 0.05) [Majority voting]
