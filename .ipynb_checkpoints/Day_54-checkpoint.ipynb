# %%
import pandas as pd


columns = ['Overall Qual', 'Overall Cond', 'Gr Liv Area',
           'Central Air', 'Total Bsmt SF', 'SalePrice']

df = pd.read_csv('http://jse.amstat.org/v19n3/decock/AmesHousing.txt', 
                 sep='\t',
                 usecols=columns)

df.head()
# Out:
#    Overall Qual  Overall Cond  Total Bsmt SF Central Air  Gr Liv Area  \
# 0             6             5         1080.0           Y         1656
# 1             5             6          882.0           Y          896
# 2             6             6         1329.0           Y         1329
# 3             7             5         2110.0           Y         2110
# 4             5             5          928.0           Y         1629
#
#    SalePrice
# 0     215000
# 1     105000
# 2     172000
# 3     244000
# 4     189900

# %%
df.shape
# Out:
# (2930, 6)

# %%
df['Central Air'] = df['Central Air'].map({'N': 0, 'Y': 1})

# %%
df.isnull().sum()
# Out:
# Overall Qual     0
# Overall Cond     0
# Total Bsmt SF    1
# Central Air      0
# Gr Liv Area      0
# SalePrice        0
# dtype: int64

# %%
# remove rows that contain missing values

df = df.dropna(axis=0)
df.isnull().sum()
# Out:
# Overall Qual     0
# Overall Cond     0
# Total Bsmt SF    0
# Central Air      0
# Gr Liv Area      0
# SalePrice        0
# dtype: int64

# %%
pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 1.1 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.24.2 in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from mlxtend) (1.2.4)
# Requirement already satisfied: setuptools in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from mlxtend) (52.0.0.post20210125)
# Requirement already satisfied: numpy>=1.16.2 in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from mlxtend) (1.20.1)
# Requirement already satisfied: scipy>=1.2.1 in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from mlxtend) (1.7.3)
# Requirement already satisfied: joblib>=0.13.2 in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from mlxtend) (1.0.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from mlxtend) (3.5.1)
# Requirement already satisfied: scikit-learn>=0.20.3 in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from mlxtend) (1.0.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.0.0->mlxtend) (8.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.0.0->mlxtend) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.0.0->mlxtend) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.0.0->mlxtend) (20.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.0.0->mlxtend) (4.28.5)
# Requirement already satisfied: six in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=3.0.0->mlxtend) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.2->mlxtend) (2021.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/chinmayee/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.3->mlxtend) (2.1.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.19.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import scatterplotmatrix

# %%
scatterplotmatrix(df.values, figsize=(12, 10), 
                  names=df.columns, alpha=0.5)
plt.tight_layout()
#plt.savefig('figures/09_04.png', dpi=300)
plt.show()

# %%
import numpy as np
from mlxtend.plotting import heatmap


cm = np.corrcoef(df.values.T)
hm = heatmap(cm, row_names=df.columns, column_names=df.columns)

plt.tight_layout()
#plt.savefig('figures/09_05.png', dpi=300)
plt.show()
