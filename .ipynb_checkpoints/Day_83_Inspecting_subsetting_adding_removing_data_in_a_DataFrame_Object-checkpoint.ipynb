# %%
import numpy as np
import pandas as pd


df = pd.read_csv('Dataset/earthquakes.csv')

# %%
df.empty
# Out:
# False

# %%
df.shape
# Out:
# (9332, 26)

# %%
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url'],
#       dtype='object')

# %%
df.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...     ,ci,  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...     ,ci,  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...     ,nc,  automatic
#
# ...

# %%
df.tail()
# Out:
#      alert  cdi        code  \
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail     dmin  felt    gap  \
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.01806   NaN  185.0
# 9328  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.03041   NaN   50.0
# 9329  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.45260   NaN  276.0
# 9330  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.01865   NaN   61.0
# 9331  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.01698   NaN   39.0
#
#                  ids   mag magType  ...  sources    status           time  \
# 9327    ,nc73086771,  0.62      md  ...     ,nc,  reviewed  1537230228060
# 9328    ,ci38063967,  1.00      ml  ...     ,ci,  reviewed  1537230135130
# 9329  ,pr2018261000,  2.40      md  ...     ,pr,  reviewed  1537229908180
# ...

# %%
df.dtypes
# Out:
# alert       object
# cdi        float64
# code        object
# detail      object
# dmin       float64
# felt       float64
# gap        float64
# ids         object
# mag        float64
# magType     object
# mmi        float64
# net         object
# nst        float64
# place       object
# rms        float64
# sig          int64
# sources     object
# status      object
# time         int64
# title       object
# tsunami      int64
# type        object
# types       object
# tz         float64
# updated      int64
# url         object
# dtype: object

# %% [markdown]
# ### Getting information and finding Null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9332 entries, 0 to 9331
# Data columns (total 26 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alert    59 non-null     object
#  1   cdi      329 non-null    float64
#  2   code     9332 non-null   object
#  3   detail   9332 non-null   object
#  4   dmin     6139 non-null   float64
#  5   felt     329 non-null    float64
#  6   gap      6164 non-null   float64
#  7   ids      9332 non-null   object
#  8   mag      9331 non-null   float64
#  9   magType  9331 non-null   object
#  10  mmi      93 non-null     float64
#  11  net      9332 non-null   object
#  12  nst      5364 non-null   float64
#  13  place    9332 non-null   object
#  14  rms      9332 non-null   float64
#  15  sig      9332 non-null   int64
#  16  sources  9332 non-null   object
#  17  status   9332 non-null   object
#  18  time     9332 non-null   int64
#  19  title    9332 non-null   object
# ...

# %% [markdown]
# ### Getting summary of Statistics

# %%
df.describe()
# Out:
#               cdi         dmin        felt          gap          mag  \
# count  329.000000  6139.000000  329.000000  6164.000000  9331.000000
# mean     2.754711     0.544925   12.310030   121.506588     1.497345
# std      1.010637     2.214305   48.954944    72.962363     1.203347
# min      0.000000     0.000648    0.000000    12.000000    -1.260000
# 25%      2.000000     0.020425    1.000000    66.142500     0.720000
# 50%      2.700000     0.059050    2.000000   105.000000     1.300000
# 75%      3.300000     0.177250    5.000000   159.000000     1.900000
# max      8.400000    53.737000  580.000000   355.910000     7.500000
#
#              mmi          nst          rms          sig          time  \
# count  93.000000  5364.000000  9332.000000  9332.000000  9.332000e+03
# mean    3.651398    19.053878     0.362122    56.899914  1.538284e+12
# std     1.790523    15.492315     0.317784    91.872163  6.080306e+08
# ...

# %% [markdown]
# ####  We can choose the percentiles we want to print
# specifying 85th and 95th percentile

# %%
df.describe(percentiles=[0.85,0.95])
# Out:
#               cdi         dmin        felt          gap          mag  \
# count  329.000000  6139.000000  329.000000  6164.000000  9331.000000
# mean     2.754711     0.544925   12.310030   121.506588     1.497345
# std      1.010637     2.214305   48.954944    72.962363     1.203347
# min      0.000000     0.000648    0.000000    12.000000    -1.260000
# 50%      2.700000     0.059050    2.000000   105.000000     1.300000
# 85%      3.800000     0.542000    9.800000   200.856000     2.410000
# 95%      4.300000     2.678900   40.200000   276.000000     4.400000
# max      8.400000    53.737000  580.000000   355.910000     7.500000
#
#              mmi          nst          rms          sig          time  \
# count  93.000000  5364.000000  9332.000000  9332.000000  9.332000e+03
# mean    3.651398    19.053878     0.362122    56.899914  1.538284e+12
# std     1.790523    15.492315     0.317784    91.872163  6.080306e+08
# ...

# %% [markdown]
# ##### Describing specific data types

# %%
df.describe(include=np.object_)
# Out:
#         alert      code                                             detail  \
# count      59      9332                                               9332
# unique      2      9332                                               9332
# top     green  61427837  https://earthquake.usgs.gov/fdsnws/event/1/que...
# freq       58         1                                                  1
#
#                  ids magType   net                   place sources    status  \
# count           9332    9331  9332                    9332    9332      9332
# unique          9332      10    14                    5433      52         2
# top     ,nn00660311,      ml    ak  10km NE of Aguanga, CA    ,ak,  reviewed
# freq               1    6803  3166                     306    2981      7797
#
#                                  title        type  \
# count                             9332        9332
# unique                            7807           5
# ...

# %%
df.describe(include='all')
# Out:
#         alert         cdi      code  \
# count      59  329.000000      9332
# unique      2         NaN      9332
# top     green         NaN  61427837
# freq       58         NaN         1
# mean      NaN    2.754711       NaN
# std       NaN    1.010637       NaN
# min       NaN    0.000000       NaN
# 25%       NaN    2.000000       NaN
# 50%       NaN    2.700000       NaN
# 75%       NaN    3.300000       NaN
# max       NaN    8.400000       NaN
#
#                                                    detail         dmin  \
# count                                                9332  6139.000000
# unique                                               9332          NaN
# top     https://earthquake.usgs.gov/fdsnws/event/1/que...          NaN
# freq                                                    1          NaN
# mean                                                  NaN     0.544925
# std                                                   NaN     2.214305
# ...

# %%
df.felt.describe() # For the felt column
# Out:
# count    329.000000
# mean      12.310030
# std       48.954944
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max      580.000000
# Name: felt, dtype: float64

# %%
df.ids.describe() # For the ids column
# Out:
# count             9332
# unique            9332
# top       ,nn00660311,
# freq                 1
# Name: ids, dtype: object

# %%
df.felt.unique()
# Out:
# array([ nan,  28.,   1.,  11.,   7.,  13.,   9.,  64.,  19.,   3.,   6.,
#          2.,  15.,  59.,   5.,   4.,   8., 170.,  10.,  54., 157.,  25.,
#         33.,  17.,   0., 185.,  23., 580.,  18., 198., 488., 101.,  38.,
#        155.,  20.,  39.,  12.,  14.,  41., 159.,  27.,  63., 179.,  53.,
#         85.])

# %% [markdown]
# ### Subsetting the data

# %%
# Grabbing an entire column using attribute notation
df.tsunami
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9327    0
# 9328    0
# 9329    0
# 9330    0
# 9331    0
# Name: tsunami, Length: 9332, dtype: int64

# %%
# Grabbing an entire column using dictionary syntax
df['tsunami']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9327    0
# 9328    0
# 9329    0
# 9330    0
# 9331    0
# Name: tsunami, Length: 9332, dtype: int64

# %%
df[['tsunami','mag']]
# Out:
#       tsunami   mag
# 0           0  1.35
# 1           0  1.29
# 2           0  3.42
# 3           0  0.44
# 4           0  2.16
# ...       ...   ...
# 9327        0  0.62
# 9328        0  1.00
# 9329        0  2.40
# 9330        0  1.10
# 9331        0  0.66
#
# [9332 rows x 2 columns]

# %%
# Selecting columns using list comprehensions and string operations:
df[
    
    ['title','tsunami']
    +[col for col in df.columns if col.startswith('mag')]
    
]
# Out:
#                                          title  tsunami   mag magType
# 0                M 1.4 - 9km NE of Aguanga, CA        0  1.35      ml
# 1                M 1.3 - 9km NE of Aguanga, CA        0  1.29      ml
# 2                M 3.4 - 8km NE of Aguanga, CA        0  3.42      ml
# 3                M 0.4 - 9km NE of Aguanga, CA        0  0.44      ml
# 4                M 2.2 - 10km NW of Avenal, CA        0  2.16      md
# ...                                        ...      ...   ...     ...
# 9327      M 0.6 - 9km ENE of Mammoth Lakes, CA        0  0.62      md
# 9328               M 1.0 - 3km W of Julian, CA        0  1.00      ml
# 9329  M 2.4 - 35km NNE of Hatillo, Puerto Rico        0  2.40      md
# 9330             M 1.1 - 9km NE of Aguanga, CA        0  1.10      ml
# 9331             M 0.7 - 9km NE of Aguanga, CA        0  0.66      ml
#
# [9332 rows x 4 columns]

# %%
[col for col in df.columns if col.startswith('mag')]
# Out:
# ['mag', 'magType']

# %%
['title','tsunami']\
+[col for col in df.columns if col.startswith('mag')]
# Out:
# ['title', 'tsunami', 'mag', 'magType']

# %% [markdown]
# ### Slicing

# %%
df[90:93]
# Out:
#    alert  cdi      code                                             detail  \
# 90   NaN  4.5  73096771  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 91   NaN  NaN  1000hbp3  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 92   NaN  NaN  1000hbp4  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#         dmin  felt    gap                      ids   mag magType  ...  \
# 90  0.009227  11.0   50.0  ,nc73096771,us1000hbp6,  3.22      ml  ...
# 91  1.379000   NaN  144.0             ,us1000hbp3,  4.70      mb  ...
# 92  6.603000   NaN  132.0             ,us1000hbp4,  4.60      mb  ...
#
#     sources     status           time                                   title  \
# 90  ,nc,us,  automatic  1539438366550        M 3.2 - 6km NNW of Pinnacles, CA
# 91     ,us,   reviewed  1539437762090      M 4.7 - 32km SE of Muisne, Ecuador
# 92     ,us,   reviewed  1539437595250  M 4.6 - 150km E of Luganville, Vanuatu
#
# ...

# %%
df[['tsunami','mag']][11:15]
# Out:
#     tsunami   mag
# 11        0  2.77
# 12        0  0.50
# 13        0  4.50
# 14        0  2.13

# %%
df[11:15][['tsunami','mag']]
# Out:
#     tsunami   mag
# 11        0  2.77
# 12        0  0.50
# 13        0  4.50
# 14        0  2.13

# %%
df[11:15]['title'] = df[11:15]['title'].str.lower()
# Out:
# <ipython-input-32-4072558f8311>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[11:15]['title'] = df[11:15]['title'].str.lower()

# %%
print(df[11:15]['title'])
# Out:
# 11    m 2.8 - 53km se of punta cana, dominican republic
# 12                        m 0.5 - 9km ne of aguanga, ca
# 13           m 4.5 - 120km ssw of banda aceh, indonesia
# 14                     m 2.1 - 14km nw of parkfield, ca
# Name: title, dtype: object

# %%
df.loc[11:15,'title'] = df.loc[11:15,'title'].str.lower() 
df.loc[11:15,'title']
# Out:
# 11    m 2.8 - 53km se of punta cana, dominican republic
# 12                        m 0.5 - 9km ne of aguanga, ca
# 13           m 4.5 - 120km ssw of banda aceh, indonesia
# 14                     m 2.1 - 14km nw of parkfield, ca
# 15         m 2.0 - 156km wnw of haines junction, canada
# Name: title, dtype: object

# %%
df.loc[11:15,['title']] # This includes the ending Index
# Out:
#                                                 title
# 11  m 2.8 - 53km se of punta cana, dominican republic
# 12                      m 0.5 - 9km ne of aguanga, ca
# 13         m 4.5 - 120km ssw of banda aceh, indonesia
# 14                   m 2.1 - 14km nw of parkfield, ca
# 15       m 2.0 - 156km wnw of haines junction, canada

# %%
df.iloc[10:15, 6:10].equals(
    df.loc[10:14, 'gap':'magType']
)
# Out:
# True

# %%
df.at[10,'mag']
# Out:
# 0.5

# %%
df.iat[10, 8]
# Out:
# 0.5

# %% [markdown]
# ## Filtering

# %%
df.mag >2
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 9327    False
# 9328    False
# 9329     True
# 9330    False
# 9331    False
# Name: mag, Length: 9332, dtype: bool

# %%
df[df.mag>2]
# Out:
#      alert  cdi        code  \
# 2      NaN  4.4    37389194
# 4      NaN  NaN    73096941
# 5      NaN  NaN  2018286011
# 9      NaN  NaN    1000hbtn
# 11     NaN  NaN  2018286010
# ...    ...  ...         ...
# 9317   NaN  NaN    38064023
# 9319   NaN  NaN    2000hg5w
# 9320   NaN  NaN    38064007
# 9321   NaN  NaN    2000hjsq
# 9329   NaN  NaN  2018261000
#
#                                                  detail     dmin  felt    gap  \
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.02137  28.0   21.0
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.07799   NaN  192.0
# 5     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.43730   NaN  158.0
# 9     https://earthquake.usgs.gov/fdsnws/event/1/que...  3.19100   NaN   37.0
# 11    https://earthquake.usgs.gov/fdsnws/event/1/que...  0.94770   NaN  186.0
# ...                                                 ...      ...   ...    ...
# ...

# %%
df.loc[
    df.mag >= 7.0,
    ['alert', 'mag', 'magType', 'title', 'tsunami', 'type']
]
# Out:
#       alert  mag magType                                       title  tsunami  \
# 837   green  7.0     mww  M 7.0 - 117km E of Kimbe, Papua New Guinea        1
# 5263    red  7.5     mww           M 7.5 - 78km N of Palu, Indonesia        1
#
#             type
# 837   earthquake
# 5263  earthquake
